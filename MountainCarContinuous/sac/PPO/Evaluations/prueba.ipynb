# %%
from numpy import load
with load('evaluations_ppo_mountain_car.npz') as data:
    lst = data.files
    for item in lst:
        print(item)
        print(data[item])
# Out:
# timesteps
# [ 10000  20000  30000  40000  50000  60000  70000  80000  90000 100000
#  110000 120000 130000 140000 150000 160000 170000 180000 190000 200000
#  210000 220000 230000 240000 250000 260000 270000 280000 290000 300000
#  310000 320000 330000 340000 350000 360000 370000 380000 390000 400000
#  410000 420000 430000 440000 450000 460000 470000 480000 490000 500000]
# results
# [[-51.264216 -62.744782 -49.895428 -71.913659 -52.279125 -57.272469
#   -69.171132 -62.611983 -67.911024 -68.645433]
#  [-89.652717 -89.838335 -89.964607 -90.946802 -90.548023 -90.211343
#   -90.41369  -90.845509 -90.345733 -90.571229]
#  [ 35.079803  27.202281  32.123079  16.358705  43.037429  10.847589
#    24.680121  34.917252  26.765843  42.71313 ]
#  [-99.9      -99.9      -99.9      -99.9      -99.9      -99.9
#   -99.9      -99.821975 -99.9      -99.9     ]
#  [ 88.71619   88.637811  88.608163  85.748224  87.650978  88.726559
#    87.349504  83.946154  88.612045  88.152267]
# ...
